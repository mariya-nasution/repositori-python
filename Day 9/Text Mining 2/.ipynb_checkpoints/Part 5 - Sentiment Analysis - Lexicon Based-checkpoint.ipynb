# %% [markdown]
# # Sentiment Analysis - Lexicon Based
#
# Sentiment Analysis merujuk pada penggunaan *natural language processing*, analisis teks, linguistik komputasional, dan biometrik yang secara sistematis mengidentifikasi, mengekstrak, memperhitungkan dan mempelajari kondisi afektif atau informasi subjektif.
#
# ![Sentiment Analysis](./images/sentiment-analysis.jpg)
#
# Sumber: https://www.kdnuggets.com/2018/03/5-things-sentiment-analysis-classification.html
#
# Ada beberapa metode yang biasanya digunakan dalam analisa sentimen, diantaranya adalah:
#
# - Lexicon-Based. Metode ini menggunakan variasi dari kata yang sudah ditandai nilai sentimennya. Dengan metode ini kita tidak perlu melakukan training model, sangat baik jika untuk membuat prototipe aplikasi maupun pada tahap awal pembangunan korpus sentimen.
#
# - Machine Learning-Based. Metode ini menggunaan model machine learning untuk mengklasifikasikan dokumen/teks ke dalam sentimen tertentu. Sangat cocok ketika sudah memiliki korpus yang sangat besar.
#
# - Hybrid-Based. Metode ini mencampurkan kedua metode diatas.
#
# ![Sentiment Analysis 2](./images/sentiment-analysis-2.jpg)
#
# Sumber: https://www.kdnuggets.com/2018/03/5-things-sentiment-analysis-classification.html

# %% [markdown]
# ## Alur Kerja Sentiment Analysis
#
# Alur kerja klasik dari sentiment analysis dapat dilihat pada gambar berikut:
#
# ![Sentiment Analysis 3](./images/sentiment-analysis-3.png)
#
# Sumber: https://www.datacamp.com/community/tutorials/simplifying-sentiment-analysis-python

# %% [markdown]
# ## Load Library

# %%
import pandas as pd
import gensim

# %% [markdown]
# ## Load Dataset

# %%
raw_data = pd.read_csv("./data/berita.csv", delimiter=';')

raw_data = raw_data.dropna()

raw_data.head()
# Out:
#                                                judul     tanggal  \
# 0  Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...  2019-03-25
# 1  KKP Terus Lakukan Langkah Masif, Produksi Tuna...  2019-03-25
# 2  Ada Aturan Besaran Tarif Ojek Online, Bagaiman...  2019-03-25
# 3  Aplikator Boleh Patok Harga Lebih Besar 20 Per...  2019-03-25
# 4  Menurut Bill Gates, Lakukan Trik Ini agar Suks...  2019-03-25
#
#                                           isi_berita
# 0  Pemerintah meminta dunia usaha khususnya para ...
# 1  Indonesia telah mengalami peningkatan produksi...
# 2  Kementerian Perhubungan (Kemenhub) telah menet...
# 3  Dirjen Perhubungan Darat Kementerian Perhubung...
# 4  Pendiri Microsoft dan miliarder  Bill Gates me...

# %% [markdown]
# ## Load Dataset Sentimen

# %%
sentimen = pd.read_csv('./data/sentimen.csv')

sentimen.head()
# Out:
#              kata sentimen
# 0              a+  positif
# 1  acungan jempol  positif
# 2         adaptif  positif
# 3            adil  positif
# 4        afinitas  positif

# %% [markdown]
# ## Simple Preprocess

# %%
raw_data['isi_berita'] = raw_data['isi_berita'].apply(lambda x: gensim.utils.simple_preprocess(x)).copy()
raw_data
# Out:
#                                                  judul     tanggal  \
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...  2019-03-25
# 1    KKP Terus Lakukan Langkah Masif, Produksi Tuna...  2019-03-25
# 2    Ada Aturan Besaran Tarif Ojek Online, Bagaiman...  2019-03-25
# 3    Aplikator Boleh Patok Harga Lebih Besar 20 Per...  2019-03-25
# 4    Menurut Bill Gates, Lakukan Trik Ini agar Suks...  2019-03-25
# ..                                                 ...         ...
# 514       Aprindo: Konsumen Indonesia Makin Berwawasan  2019-03-11
# 515  Meski Jauh dari Target, Ekonomi Indonesia Cata...  2019-03-11
# 516  Siap-Siap, Mobil Murah Bakal Dikenakan Pajak P...  2019-03-11
# 517                      UOB Gandeng Aplikasi UrbanAce  2019-03-11
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...  2019-03-11
#
#                                             isi_berita
# 0    [pemerintah, meminta, dunia, usaha, khususnya,...
# 1    [indonesia, telah, mengalami, peningkatan, pro...
# 2    [kementerian, perhubungan, kemenhub, telah, me...
# 3    [dirjen, perhubungan, darat, kementerian, perh...
# 4    [pendiri, microsoft, dan, miliarder, bill, gat...
# ..                                                 ...
# 514  [turunnya, pertumbuhan, perdagangan, ritel, se...
# 515  [pertumbuhan, ekonomi, indonesia, terus, posit...
# 516  [insiatif, fiskal, berupa, pajak, penjualan, a...
# 517  [uob, indonesia, menggandeng, aplikasi, selule...
# 518  [pt, bank, syariah, mandiri, atau, mandiri, sy...
#
# [518 rows x 3 columns]

# %% [markdown]
# **Ambil Kolom ```judul``` dan ```isi_berita```**

# %%
analisa = raw_data.iloc[:,[0,2]]

analisa
# Out:
#                                                  judul  \
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...
# 1    KKP Terus Lakukan Langkah Masif, Produksi Tuna...
# 2    Ada Aturan Besaran Tarif Ojek Online, Bagaiman...
# 3    Aplikator Boleh Patok Harga Lebih Besar 20 Per...
# 4    Menurut Bill Gates, Lakukan Trik Ini agar Suks...
# ..                                                 ...
# 514       Aprindo: Konsumen Indonesia Makin Berwawasan
# 515  Meski Jauh dari Target, Ekonomi Indonesia Cata...
# 516  Siap-Siap, Mobil Murah Bakal Dikenakan Pajak P...
# 517                      UOB Gandeng Aplikasi UrbanAce
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...
#
#                                             isi_berita
# 0    [pemerintah, meminta, dunia, usaha, khususnya,...
# 1    [indonesia, telah, mengalami, peningkatan, pro...
# 2    [kementerian, perhubungan, kemenhub, telah, me...
# 3    [dirjen, perhubungan, darat, kementerian, perh...
# 4    [pendiri, microsoft, dan, miliarder, bill, gat...
# ..                                                 ...
# 514  [turunnya, pertumbuhan, perdagangan, ritel, se...
# 515  [pertumbuhan, ekonomi, indonesia, terus, posit...
# 516  [insiatif, fiskal, berupa, pajak, penjualan, a...
# 517  [uob, indonesia, menggandeng, aplikasi, selule...
# 518  [pt, bank, syariah, mandiri, atau, mandiri, sy...
#
# [518 rows x 2 columns]

# %% [markdown]
# **Ubah list setiap ```isi_berita``` menjadi ```record```**

# %%
analisa = analisa.explode('isi_berita')

analisa
# Out:
#                                                  judul  isi_berita
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...  pemerintah
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...     meminta
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...       dunia
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...       usaha
# 0    Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...   khususnya
# ..                                                 ...         ...
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...        bank
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...     syariah
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...     mandiri
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...      kusman
# 518  BSM Targetkan Pertumbuhan KPR di Atas 10 Perse...       yandi
#
# [158342 rows x 2 columns]

# %% [markdown]
# **Lakukan proses inner join antara objek ```analisa``` dan ```sentimen```**

# %%
hasil_join = pd.merge(left=analisa, right=sentimen, left_on='isi_berita', right_on='kata')

hasil_join
# Out:
#                                                    judul isi_berita  \
# 0      Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...  menggugat
# 1      Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...  menggugat
# 2      Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...  menggugat
# 3      Lawan Diskriminasi CPO, Pemerintah Ajak Pebisn...   disahkan
# 4      CPO Didiskriminasi, Pemerintah Galang Dukungan...   disahkan
# ...                                                  ...        ...
# 15897  Astra Akan Beri Hadiah Bagi Generasi Muda yang...       diam
# 15898  Astra Akan Beri Hadiah Bagi Generasi Muda yang...       diam
# 15899  Gandeng Pihak Swasta, Kemendag Perkuat Akses U...    tangkas
# 15900  Pesawat Ethiopian Airlines Jatuh, Saham Boeing...   terberat
# 15901  Meski Jauh dari Target, Ekonomi Indonesia Cata...   penolong
#
#             kata sentimen
# 0      menggugat  negatif
# 1      menggugat  negatif
# 2      menggugat  negatif
# 3       disahkan  positif
# 4       disahkan  positif
# ...          ...      ...
# 15897       diam  positif
# 15898       diam  negatif
# 15899    tangkas  positif
# 15900   terberat  positif
# 15901   penolong  positif
#
# [15902 rows x 4 columns]

# %% [markdown]
# **Agregasi Sentimen**

# %%
hasil_join = hasil_join.iloc[:,[0,3]].assign(nilai_sentimen=0).groupby(['judul','sentimen'], as_index=False).count()

hasil_join
# Out:
#                                                   judul sentimen  \
# 0     "Corn Planter", Ini Mesin yang Berperan Mening...  negatif
# 1     "Corn Planter", Ini Mesin yang Berperan Mening...  positif
# 2     "Market Cap" Tembus Rp 500 Triliun, BRI Cetak ...  negatif
# 3     "Market Cap" Tembus Rp 500 Triliun, BRI Cetak ...  positif
# 4           10 Cara Ini Bikin Anda Tanpa Sadar Berhemat  negatif
# ...                                                 ...      ...
# 1020  [POPULER MONEY] Skandal Seks Pengaruhi Saham P...  positif
# 1021  [POPULER MONEY] Tips Berburu Tiket Pesawat Mur...  negatif
# 1022  [POPULER MONEY] Tips Berburu Tiket Pesawat Mur...  positif
# 1023  “Upgrade” Metode Pelatihan Kerja Agar Masyarak...  negatif
# 1024  “Upgrade” Metode Pelatihan Kerja Agar Masyarak...  positif
#
#       nilai_sentimen
# 0                 10
# 1                 19
# 2                  6
# 3                 14
# 4                 32
# ...              ...
# 1020              15
# 1021              18
# 1022              26
# 1023               2
# 1024              18
#
# [1025 rows x 3 columns]

# %% [markdown]
# **Ubah dari ```pivot_table``` kembali ke bentuk ```dataframe```**

# %%
hasil_join = hasil_join.pivot_table(index='judul', columns='sentimen', values='nilai_sentimen', fill_value=0).to_records()

hasil_join

# %% [markdown]
# **Membuat kolom baru ```sentimen```**

# %%
hasil_join = pd.DataFrame(hasil_join).assign(sentimen=0)

hasil_join

# %% [markdown]
# **Hitung nilai sentimen**

# %%
hasil_join['sentimen'] = hasil_join['positif'] - hasil_join['negatif']
hasil_join
# Out:
#                                                  judul  negatif  positif  \
# 0    "Corn Planter", Ini Mesin yang Berperan Mening...       10       19
# 1    "Market Cap" Tembus Rp 500 Triliun, BRI Cetak ...        6       14
# 2          10 Cara Ini Bikin Anda Tanpa Sadar Berhemat       32       30
# 3    10 Pesawat Boeing 737 Max 8 Alami "Grounding,"...        3        7
# 4    10.000 Pengusaha Deklarasi Dukung Jokowi-Ma'ru...       18       28
# ..                                                 ...      ...      ...
# 511  [POPULER MONEY] Lowongan di BUMN| Gaji Baru Po...        2        1
# 512  [POPULER MONEY] RI Resmi Larang Terbang Boeing...        3        1
# 513  [POPULER MONEY] Skandal Seks Pengaruhi Saham P...       19       15
# 514  [POPULER MONEY] Tips Berburu Tiket Pesawat Mur...       18       26
# 515  “Upgrade” Metode Pelatihan Kerja Agar Masyarak...        2       18
#
#      sentimen
# 0           9
# 1           8
# 2          -2
# 3           4
# 4          10
# ..        ...
# 511        -1
# 512        -2
# 513        -4
# 514         8
# 515        16
#
# [516 rows x 4 columns]

# %%
# melihat sentimen 10 berita pertama
hasil_join[['judul','sentimen']].iloc[0:10].plot.barh(x='judul',y='sentimen');

# %% [markdown]
# **Plot menggunakan seaborn**

# %%
def warna(sentimen):
    war = []
    for sent in sentimen:
        if sent >=0:
            war.append("positif")
        else:
            war.append("negatif")
    return war

# %%
hasil_join = hasil_join[['judul','sentimen']].assign(warna=warna(hasil_join['sentimen'].tolist()))

hasil_join
# Out:
#                                                  judul  sentimen    warna
# 0    "Corn Planter", Ini Mesin yang Berperan Mening...         9  positif
# 1    "Market Cap" Tembus Rp 500 Triliun, BRI Cetak ...         8  positif
# 2          10 Cara Ini Bikin Anda Tanpa Sadar Berhemat        -2  negatif
# 3    10 Pesawat Boeing 737 Max 8 Alami "Grounding,"...         4  positif
# 4    10.000 Pengusaha Deklarasi Dukung Jokowi-Ma'ru...        10  positif
# ..                                                 ...       ...      ...
# 511  [POPULER MONEY] Lowongan di BUMN| Gaji Baru Po...        -1  negatif
# 512  [POPULER MONEY] RI Resmi Larang Terbang Boeing...        -2  negatif
# 513  [POPULER MONEY] Skandal Seks Pengaruhi Saham P...        -4  negatif
# 514  [POPULER MONEY] Tips Berburu Tiket Pesawat Mur...         8  positif
# 515  “Upgrade” Metode Pelatihan Kerja Agar Masyarak...        16  positif
#
# [516 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.barplot(x='sentimen', y='judul', hue='warna', data=hasil_join.iloc[0:10,]);
